# %%
#buat variabel skalar x dan simpan suatu nilai skalar#
x = 112

# %%
#tampilkan tipe data dari x#
type (x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar#
y = 121

# %%
#buat variabel skalar y dan simpan suatu nilai skalar#
type (y)
# Out:
# int

# %%
#jumlahkan x+y#
py_sum = x + y
py_sum
# Out:
# 233

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal #
x_float = 21.1

# %%
#jumlahkan x_float dengan y#
float_sum = x_float + y
float_sum
# Out:
# 142.1

# %%
#tampilkan tipe data dari x_float
type (float_sum)
# Out:
# float

# %% [markdown]
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_tf = 112
x_tf
# Out:
# 112

# %%
# tampilkan tipe data dari x
x_tf = tf.Variable(121, dtype=tf.int32)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=121>

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_tf = 15
y_tf

# %%
# tampilkan tipe data dari y
y_tf = tf.Variable(15, dtype=tf.int32)
y_tf

# %%
# jumlahkan x+y
tf_sum = tf.add(x_tf, y_tf)
tf_sum

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
xtf_float = 10.5
xtf_float

# %%
# tampilkan tipe data dari x_float
xtf_float = tf.Variable(10.5, dtype=tf.float16)
xtf_float

# %% [markdown]
# 3. lakukan tahapan pada soal 1 dengan menggunakan PyTorch

# %%
import torch as pt

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_pt = 211
x_pt

# %%
# tampilkan tipe data dari x
x_pt = pt.tensor(211, dtype=pt.int32)
x_pt

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_pt = 21
y_pt

# %%
# tampilkan tipe data dari y
y_pt = pt.tensor(15, dtype=pt.int32)
y_pt

# %%
# jumlahkan x+y
x_pt + y_pt

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
xpt_float = 10.5

# %%
# jumlahkan x_float dengan y
ptfloat_sum = pt.add(xpt_float, y_pt)
ptfloat_sum

# %%
xpt_float = pt.tensor(10.5, dtype=pt.float16)
xpt_float
