# %%
import numpy as np

# %%
# vektor kolom
v = np.array([[25],
              [2],
              [-3],
              [-23]])

# %%
# transpose
v_transpose = v.T

print("Vektor awal:")
print(v)

print("\nTranspose vektor:")
print(v_transpose)
# Out:
# Vektor awal:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
#
# Transpose vektor:
# [[ 25   2  -3 -23]]
